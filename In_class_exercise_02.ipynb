# %% [markdown]
# <a href="https://colab.research.google.com/github/PrudhviNarayanKorupolu/KorupoluExercise2/blob/main/In_class_exercise_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (9/15/2021, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:

I have an interest in drowsiness detection technology, which collects the live feed video data to analze the driver's
current state, video is processed as frames per second we analze each frame and find face and eyes in frame and calculate
gap between eye lids which we can compare it with minimun thershold thereby we can implement immediate action.

* image/video streamline data needed which can obtained by camera.
* For  this project we need live/streamlined data.
*The input should be given via the sensors or camera which ae further fed as input to algorithm and the the ouput will be taken out after processing the data







'''

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 reviews of a movie from IMDB (https://www.imdb.com/) or 1000 reviews of a product from Amazon (https://www.amazon.com/).
#
# As for the IMDB movie review, the following informtion need to be collected (for example: https://www.imdb.com/title/tt6751668/reviews?ref_=tt_urv):
#
# (1) User name
#
# (2) Star
#
# (3) Review title
#
# (4) Review text
#
# (5) Review posted time
#
#
# As for the Amazon product review, the following information need to be collected (for example: https://www.amazon.com/Hands-Machine-Learning-Scikit-Learn-TensorFlow/dp/1492032646/ref=sr_1_3?crid=2E3C55VKJX0K3&dchild=1&keywords=machine+learning+andrew+ng&qid=1631718619&sr=8-3):
#
# (1) User name
#
# (2) Star
#
# (3) Review title
#
# (4) Review text
#
# (5) Review posted time

# %%
from requests import get

url = get("https://www.imdb.com/title/tt2304655/reviews/?ref_=tt_ql_urv")
request = url.text
from bs4 import BeautifulSoup as Soup 
soup_data=Soup(request,'html.parser')


R_title = []
R_star = []
R_username = []
R_body = []
R_posted = []

# Fetching the text
print(soup_data.title.text)

movies = soup_data.findAll('div',{'class':'lister-item-content'})

for review_title in movies:
  R_title.append(review_title.a.text)



stars = soup_data.find_all('span',{'class':'rating-other-user-rating'})

for star in stars:
  R_star.append(star.span.text)

usernames = soup_data.findAll('span',{'class':'display-name-link'})

for user in usernames:
  R_username.append(user.a.text)

posttime = soup_data.findAll('span',{'class':'review-date'})

for ptime in posttime:
  R_posted.append(posttime[0].text)

review = soup_data.findAll('div',{'class':'text show-more__control'})

for re in review:
  R_body.append(re.text)


for i in range(len(movies)):
  print(str(i+1)+'. )'+'Title :'+R_title[i]+'\n username:'+R_username[i]+'\n star:'+R_star[i]+'\n posted time:'+R_posted[i]+'\n review:' +R_body[i])
# Out:
# Gabbar Singh (2012) - Gabbar Singh (2012) - User Reviews - IMDb
# 16 16 16 16 16
# 1. )Title : GABBAR SINGH - Pure entertainer! One man show! Power Star is back with a bang!!!
#
#  username:bharath882005
#  star:10
#  posted time:17 May 2012
# ...

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
from requests import get

url = get("https://citeseerx.ist.psu.edu/search?q=technology&submit.x=0&submit.y=0&sort=rlv&t=doc")
request = url.text
from bs4 import BeautifulSoup as Soup
soup_data=Soup(request,'html.parser')

titles_l = []
authors_l = []
years_l = []
abstracts_l = []

titles = soup_data.findAll('a',{'class':'remove doc_details'})

for title in titles:
  titles_l.append(title.text.strip())

authors = soup_data.findAll('span',{'class':'authors'})

for author in authors:
  authors_l.append(author.text.replace('by','').strip())

years = soup_data.findAll('span',{'class':'pubyear'})

for year in years:
  years_l.append(year.text.replace(',','').strip())

abstracts = soup_data.findAll('div',{'class':'snippet'})

for abstract in abstracts:
  abstracts_l.append(abstract.text.strip())


for i in range(len(titles)):
  print(str(i+1)+'. )'+'Title :'+titles_l[i]+'\n author:'+authors_l[i]+'\n year:'+years_l[i]+'\n abstract:'+abstracts_l[i]+'\n review:' +R_body[i])
# Out:
# 1. )Title :Endogenous technological change
#  author:Paul M. Romer
#  year:1990
#  abstract:"...   ..."
# ...

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
import tweepy
import time
# authorization tokens
consumer_key = "5dr"
consumer_secret = "LZCSk09y0LZ8xmNJCp"
access_key = "34Ytqpr"
access_secret = "EZtRILZ4"

# StreamListener class inherits from tweepy.StreamListener and overrides on_status/on_error methods.
class StreamListener(tweepy.StreamListener):
    def on_status(self, status):
        print(status.id_str)
        # if "retweeted_status" attribute exists, flag this tweet as a retweet.
        is_retweet = hasattr(status, "retweeted_status")


        # check if text has been truncated
        if hasattr(status,"extended_tweet"):
            text = status.extended_tweet["full_text"]
            print("Tweet :",text )
        else:
            text = status.text
            print("Tweet :",text)

        # check if this is a quote tweet.
        is_quote = hasattr(status, "quoted_status")
        quoted_text = ""
        if is_quote:
            # check if quoted tweet's text has been truncated before recording it
            if hasattr(status.quoted_status,"extended_tweet"):
                quoted_text = status.quoted_status.extended_tweet["full_text"]
                print("Quoted text :",quoted_text )
            else:
                quoted_text = status.quoted_status.text
                print("Quoted text :",quoted_text )

        # remove characters that might cause problems with csv encoding
        remove_characters = [",","\n"]
        for c in remove_characters:
            text.replace(c," ")
            quoted_text.replace(c, " ")

        with open("out.csv", "a", encoding='utf-8') as f:
            f.write("%s,%s,%s,%s,%s,%s\n" % (status.created_at,status.user.screen_name,is_retweet,is_quote,text,quoted_text))
        
        

    def on_error(self, status_code):
        print("Encountered streaming error (", status_code, ")")
        

if __name__ == "__main__":
    # complete authorization and initialize API endpoint
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)

    # initialize stream
    streamListener = StreamListener()
    stream = tweepy.Stream(auth=api.auth, listener=streamListener,tweet_mode='extended')
    with open("out.csv", "w", encoding='utf-8') as f:
        f.write("date,user,is_retweet,is_quote,text,quoted_text\n")
    tags = ["love"]
    stream.filter(track=tags)
    
    # stream = Stream(auth, StreamListener())
    # stream.filter(track=['twitter']) #apply any filter you want
# Out:
# 1439845340375666688
# Tweet : @krystoes OMG😳😳😳what an Extraordinary Phenomenal Sensational Sexy pair of Fabulous Fantastic Phenomenally Flawless FEET that you possess KRYS TOES Showcasing your Gloriously Long Lovely Luscious Tempting Talented Tantalizingly Tasty Toes that I'd love to suck on for hours and hours WOW
# 1439845340459511814
# Tweet : RT @ProfFeynman: Love yourself. But also analyze and be critical of how you think, act &amp; behave. Self love without self awareness is useles…
# 1439845340836884486
# Tweet : The world needs more love and Twitter just figured.
#
# ك҉و҉د҉ ҉خ҉ص҉م҉ ҉ك҉و҉ب҉و҉ن҉  نمشي HM7
#
# کْوٌدٍ خِـصّـمً ستايلي BG092
# 1439845341063352320
# Tweet : RT @SamAdlerBell: there's a pervasive sense among right-wing pundits that non-right wingers have actively enjoyed lockdowns, masks, etc. Th…
# ...
